# %% [markdown]
# <a href="https://colab.research.google.com/github/CertifiedSlee/Project-1--Ogundeji-Solomon/blob/main/Hamoye_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url= "https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv"
url_df=pd.read_csv('https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')

# %%
url_df.groupby('Item')['Item'].sum()
# Out:
# Item
# Alcohol, Non-Food      Alcohol, Non-FoodAlcohol, Non-FoodAlcohol, Non...
# Alcoholic Beverages    Alcoholic BeveragesAlcoholic BeveragesAlcoholi...
# Animal Products        Animal ProductsAnimal ProductsAnimal ProductsA...
# Animal fats            Animal fatsAnimal fatsAnimal fatsAnimal fatsAn...
# Apples and products    Apples and productsApples and productsApples a...
#                                              ...
# Vegetables, Other      Vegetables, OtherVegetables, OtherVegetables, ...
# Vegetal Products       Vegetal ProductsVegetal ProductsVegetal Produc...
# Wheat and products     Wheat and productsWheat and productsWheat and ...
# Wine                   WineWineWineWineWineWineWineWineWineWineWineWi...
# Yams                   YamsYamsYamsYamsYamsYamsYamsYamsYamsYamsYamsYa...
# Name: Item, Length: 119, dtype: object

# %%
url_df.groupby('Y2015')['Y2015'].mean()
# Out:
# Y2015
# -3161.0       -3161.0
# -2152.0       -2152.0
# -1284.0       -1284.0
# -907.0         -907.0
# -887.0         -887.0
#                ...
#  92443.0      92443.0
#  100835.0    100835.0
#  110798.0    110798.0
#  111663.0    111663.0
#  181137.0    181137.0
# Name: Y2015, Length: 4520, dtype: float64

# %%
url_df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
url_df.isnull().std()
# Out:
# Area Code       0.000000
# Area            0.000000
# Item Code       0.000000
# Item            0.000000
# Element Code    0.000000
# Element         0.000000
# Unit            0.000000
# Y2014           0.159355
# Y2015           0.157340
# Y2016           0.156695
# Y2017           0.155246
# Y2018           0.151684
# dtype: float64

# %%
url_df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
url_df.groupby('Item').sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
url_df.groupby('Element').mean()
# Out:
#                                          Area Code    Item Code  Element Code  \
# Element
# Domestic supply quantity                133.898584  2681.292729        5301.0
# Export Quantity                         136.250284  2689.201226        5911.0
# Fat supply quantity (g/capita/day)      134.391798  2694.604818         684.0
# Feed                                    133.640637  2682.719484        5521.0
# Food                                    134.243068  2688.734062        5142.0
# Food supply (kcal/capita/day)           134.434982  2694.666933         664.0
# Food supply quantity (kg/capita/yr)     134.239755  2688.155148         645.0
# Import Quantity                         133.912045  2684.562366        5611.0
# Losses                                  136.561971  2700.250373        5123.0
# Other uses (non-food)                   136.001155  2730.801963        5154.0
# Processing                              135.293532  2661.898507        5131.0
# ...
